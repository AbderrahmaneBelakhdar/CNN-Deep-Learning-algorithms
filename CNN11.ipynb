# %%
from keras import layers
from keras import models
from keras.datasets import mnist
from keras.utils import to_categorical

# Define the CNN model
model = models.Sequential()

model.add(layers.Conv2D(32, (5,5), activation='relu', input_shape=(28, 28,1)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(10, activation='softmax'))

model.summary()

# Split the data into training and test sets
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# Use the training data to train the model
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

model.fit(train_images, train_labels,
          batch_size=100,
          epochs=25,
          verbose=1)

# Test the model's accuracy with the test data
test_loss, test_acc = model.evaluate(test_images, test_labels)

print('Test accuracy:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 64)          51264
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 10)                10250
#
# =================================================================
# Total params: 62,346
# Trainable params: 62,346
# Non-trainable params: 0
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 12s 1us/step
# Epoch 1/25
# 600/600 [==============================] - 22s 35ms/step - loss: 0.9578 - accuracy: 0.7618
# Epoch 2/25
# 600/600 [==============================] - 21s 34ms/step - loss: 0.2684 - accuracy: 0.9216
# Epoch 3/25
# 600/600 [==============================] - 20s 34ms/step - loss: 0.1942 - accuracy: 0.9435
# Epoch 4/25
# 600/600 [==============================] - 20s 34ms/step - loss: 0.1562 - accuracy: 0.9554
# Epoch 5/25
# 600/600 [==============================] - 19s 31ms/step - loss: 0.1323 - accuracy: 0.9607
# Epoch 6/25
# 600/600 [==============================] - 19s 31ms/step - loss: 0.1153 - accuracy: 0.9662
# Epoch 7/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.1038 - accuracy: 0.9692
# Epoch 8/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0947 - accuracy: 0.9721
# Epoch 9/25
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0877 - accuracy: 0.9739
# Epoch 10/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0813 - accuracy: 0.9758
# Epoch 11/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0762 - accuracy: 0.9773
# Epoch 12/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0721 - accuracy: 0.9789
# Epoch 13/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0681 - accuracy: 0.9800
# Epoch 14/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0647 - accuracy: 0.9808
# Epoch 15/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0619 - accuracy: 0.9816
# Epoch 16/25
# 600/600 [==============================] - 18s 29ms/step - loss: 0.0594 - accuracy: 0.9825
# Epoch 17/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0569 - accuracy: 0.9829
# Epoch 18/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0548 - accuracy: 0.9839
# Epoch 19/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0531 - accuracy: 0.9842
# Epoch 20/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0515 - accuracy: 0.9845
# Epoch 21/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0497 - accuracy: 0.9856
# Epoch 22/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0482 - accuracy: 0.9855
# Epoch 23/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0469 - accuracy: 0.9861
# Epoch 24/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0454 - accuracy: 0.9865
# Epoch 25/25
# 600/600 [==============================] - 17s 29ms/step - loss: 0.0440 - accuracy: 0.9869
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0426 - accuracy: 0.9851
# Test accuracy: 0.9850999712944031
